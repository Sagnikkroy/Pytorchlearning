# %%
import torch
import torch.nn as nn

# %%
x=torch.tensor([1.0,4.0],requires_grad=True)
y=(x**2).mean()
y.backward()
x.grad
# Out:
# tensor([1., 4.])

# %%
x.grad.zero_()
x.grad
# Out:
# tensor([0., 0.])

# %%
class Model(nn.Module):
    def __init__(self):
        super().__init__()
        self.Linear=nn.Linear(5,1)
        self.sigmoid=nn.Sigmoid()
    def forward(self,x):
        out =self.Linear(x)
        out=self.sigmoid(out)
        return out

# %%
model=Model()
x = torch.randn(3, 5)
output = model(x)
print("\nOutput:\n", output)
# Out:
# Output:
#  tensor([[0.6406],
#         [0.4954],
#         [0.3708]], grad_fn=<SigmoidBackward0>)

# %%
class Modell(nn.Module):
    def __init__(self):
        super().__init__()
        self.network=nn.Sequential(
            nn.Linear(5,3),
            nn.ReLU(),
            nn.Linear(3,1),
            nn.Sigmoid()
        )

    def forward(self,z):
        out=self.network(z)
        return out0-

# %%
model=Modell()
z = torch.randn(3, 5)
output = model(z)
model.Linear1.weight
model.Linear1.bias
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 4
#       2 z = torch.randn(3, 5)
#       3 output = model(z)
# ----> 4 model.Linear1.weight
#       5 model.Linear1.bias
#
# File c:\Users\sanhi\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1940, in Module.__getattr__(self, name)
#    1938     if name in modules:
#    1939         return modules[name]
# -> 1940 raise AttributeError(
#    1941     f"'{type(self).__name__}' object has no attribute '{name}'"
#    1942 )
#
# AttributeError: 'Modell' object has no attribute 'Linear1'
